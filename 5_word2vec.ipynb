# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a', 'abuse', 'term', 'first', 'of', 'abuse', 'used', 'against', 'first']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of']
#     labels: ['anarchism', 'a', 'term', 'originated', 'as', 'of', 'term', 'originated', 'of', 'a', 'as', 'abuse', 'abuse', 'first', 'a', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.992660
# Nearest to during: vhdl, alois, cid, sensitive, neopaganism, yemen, haldeman, sparkling,
# Nearest to with: kerr, hieroglyphs, glorification, nis, lemmings, orientation, propensity, dies,
# Nearest to their: troopers, powerhouse, timed, milken, terrain, muppet, tod, aha,
# Nearest to use: nightclub, senatorial, archeology, due, chiles, domitia, toolkits, ethiopia,
# Nearest to for: wad, winn, blade, gdansk, isadora, php, backgammon, journ,
# Nearest to they: weep, beep, eh, reports, coupling, gayoom, kurtz, elucidated,
# Nearest to four: mordechai, overwhelm, boudica, chechens, kidney, mehmed, mountaineer, officio,
# Nearest to known: fucking, conformation, guitar, hendrix, honecker, project, galil, pains,
# Nearest to one: imperium, reims, halfdan, fibrosis, longitudes, cadres, toured, cambridgeshire,
# Nearest to war: arisen, neonatal, adjustments, intervene, hammadi, lusp, transliterations, festus,
# Nearest to zero: axis, ripley, uvular, adam, heracleidae, notting, asclepius, bookshop,
# Nearest to seven: mua, missal, cantata, heimskringla, ol, celebrations, subsequent, rooney,
# Nearest to will: edelman, glenda, offs, jody, contraceptive, oxidative, transcript, bisexuals,
# Nearest to time: yahweh, epictetus, profiting, suicide, forfeit, hoppers, virulent, smirnov,
# Nearest to three: selective, shusui, occultation, iberville, sps, columbine, roberts, reductio,
# Nearest to history: beatification, scenic, mara, cpc, tarn, deconstructionist, interventions, gunn,
# Average loss at step 2000: 4.362856
# Average loss at step 4000: 3.865929
# Average loss at step 6000: 3.792286
# Average loss at step 8000: 3.685732
# Average loss at step 10000: 3.611785
# Nearest to during: from, vhdl, yemen, orthopedic, after, cid, dunraven, slogans,
# Nearest to with: hieroglyphs, into, in, for, awacs, cog, by, temperance,
# Nearest to their: his, its, powerhouse, showcase, cambodia, troopers, ausgleich, byers,
# Nearest to use: chiles, nightclub, fritz, ethiopia, archeology, due, logo, espionage,
# Nearest to for: of, with, on, screaming, in, daleks, ima, dispel,
# Nearest to they: he, not, it, there, who, we, ephrem, wavell,
# Nearest to four: eight, three, six, five, seven, two, nine, zero,
# Nearest to known: honecker, faa, tannenberg, machined, project, demonstrable, seattle, a,
# Nearest to one: two, three, bukem, four, eight, six, seven, five,
# Nearest to war: adjustments, mages, intervene, buber, sunspots, arisen, dissolve, meditating,
# Nearest to zero: nine, seven, eight, six, five, four, three, two,
# Nearest to seven: five, three, eight, four, six, nine, zero, two,
# Nearest to will: transcript, may, edelman, glenda, covering, mayen, offs, lysergic,
# Nearest to time: yahweh, title, eminent, evoking, homemade, somebody, profiting, skiego,
# Nearest to three: seven, four, five, six, two, eight, nine, zero,
# Nearest to history: scenic, stills, trois, bmp, lick, dodgson, beware, sem,
# Average loss at step 12000: 3.606334
# Average loss at step 14000: 3.570726
# Average loss at step 16000: 3.412163
# Average loss at step 18000: 3.454443
# Average loss at step 20000: 3.536408
# Nearest to during: after, from, orthopedic, clo, at, anthroposophy, dunraven, under,
# Nearest to with: hieroglyphs, in, for, temperance, by, into, cvn, pitts,
# Nearest to their: his, its, the, her, awful, dislike, hypocrisy, instead,
# Nearest to use: fritz, chiles, nightclub, bbc, ethiopia, surprise, bremerhaven, ari,
# Nearest to for: and, goodies, in, with, of, by, proscribed, across,
# Nearest to they: he, there, we, who, not, it, you, she,
# Nearest to four: six, eight, three, five, seven, two, nine, zero,
# Nearest to known: machined, bhp, used, such, signatories, tannenberg, honecker, well,
# Nearest to one: two, four, six, eight, three, seven, five, nine,
# Nearest to war: espoo, intervene, meditating, arisen, buber, mages, pubescent, boers,
# Nearest to zero: five, six, seven, nine, four, three, eight, two,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to will: would, may, could, should, must, can, but, gendered,
# Nearest to time: yahweh, title, evoking, profiting, skiego, eminent, somebody, tabulated,
# Nearest to three: five, six, four, two, seven, eight, zero, nine,
# Nearest to history: scenic, stills, bmp, trois, prints, garnered, hermetical, beware,
# Average loss at step 22000: 3.501414
# Average loss at step 24000: 3.490971
# Average loss at step 26000: 3.479734
# Average loss at step 28000: 3.475716
# Average loss at step 30000: 3.497846
# Nearest to during: after, in, from, under, through, dunraven, at, ottoman,
# Nearest to with: between, hieroglyphs, against, when, into, by, in, cvn,
# Nearest to their: its, his, the, her, hypocrisy, these, some, your,
# Nearest to use: bremerhaven, surprise, balalaika, hegelian, resuming, ethiopia, archeology, parcham,
# Nearest to for: zinn, without, of, represents, daleks, becomes, exceeded, label,
# Nearest to they: we, there, he, you, these, it, who, not,
# Nearest to four: five, six, eight, seven, three, two, nine, zero,
# Nearest to known: used, well, bhp, machined, such, regarded, tannenberg, honecker,
# Nearest to one: two, seven, eight, six, four, three, nine, five,
# Nearest to war: arisen, espoo, pubescent, buber, lebedev, mages, nanjing, boers,
# Nearest to zero: five, eight, seven, four, six, nine, three, two,
# Nearest to seven: eight, nine, six, five, four, three, zero, one,
# Nearest to will: would, can, may, could, should, must, might, gendered,
# Nearest to time: eminent, yahweh, evoking, title, view, misunderstanding, tabulated, vesta,
# Nearest to three: four, five, six, seven, eight, two, nine, zero,
# Nearest to history: stills, scenic, lecturing, reclassification, development, sem, circumscription, management,
# Average loss at step 32000: 3.497988
# Average loss at step 34000: 3.494517
# Average loss at step 36000: 3.452805
# Average loss at step 38000: 3.295370
# Average loss at step 40000: 3.426700
# Nearest to during: after, through, at, in, before, dunraven, under, from,
# Nearest to with: hieroglyphs, between, implants, in, by, when, pitts, pinker,
# Nearest to their: its, his, her, the, these, your, some, hypocrisy,
# Nearest to use: surprise, ethiopia, balalaika, represent, resuming, parcham, sedition, unfashionable,
# Nearest to for: causing, in, if, wobble, stock, at, aml, across,
# Nearest to they: we, there, he, you, it, these, i, not,
# Nearest to four: six, five, three, seven, eight, two, nine, zero,
# Nearest to known: used, such, regarded, well, machined, bhp, tannenberg, demonstrable,
# Nearest to one: two, seven, six, four, eight, five, three, nine,
# Nearest to war: pubescent, arisen, espoo, inn, mages, meditating, nanjing, terabytes,
# Nearest to zero: seven, nine, five, eight, six, four, two, three,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to will: would, can, may, could, must, should, might, gendered,
# Nearest to time: year, eminent, yahweh, way, misunderstanding, summarised, vesta, pfaff,
# Nearest to three: four, two, five, six, seven, eight, one, nine,
# Nearest to history: beware, stills, hermetical, reclassification, scenic, imitating, caine, maud,
# Average loss at step 42000: 3.433142
# Average loss at step 44000: 3.453285
# Average loss at step 46000: 3.448009
# Average loss at step 48000: 3.351524
# Average loss at step 50000: 3.383968
# Nearest to during: after, through, in, from, when, under, caballero, before,
# Nearest to with: between, hieroglyphs, by, cryogenics, aegean, collectivist, logitech, implants,
# Nearest to their: its, his, her, the, some, my, encoder, our,
# Nearest to use: range, ethiopia, sense, balalaika, most, transactional, surprise, unfashionable,
# Nearest to for: while, zinn, centrepiece, posthuman, dispel, after, on, custis,
# Nearest to they: we, he, there, you, she, it, cindy, these,
# Nearest to four: six, seven, five, eight, three, nine, two, zero,
# Nearest to known: used, regarded, such, well, tannenberg, demonstrable, possible, bhp,
# Nearest to one: two, six, four, eight, seven, five, three, zero,
# Nearest to war: arisen, pubescent, meditating, inn, mages, denizens, espoo, terabytes,
# Nearest to zero: eight, seven, nine, five, six, four, two, three,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to time: year, yahweh, way, balaton, period, summarised, eminent, weight,
# Nearest to three: four, six, seven, eight, nine, five, two, zero,
# Nearest to history: beware, sem, reclassification, origins, stills, hermetical, science, australopithecines,
# Average loss at step 52000: 3.440491
# Average loss at step 54000: 3.427403
# Average loss at step 56000: 3.434732
# Average loss at step 58000: 3.394995
# Average loss at step 60000: 3.394269
# Nearest to during: after, before, in, when, following, although, through, since,
# Nearest to with: between, hieroglyphs, cryogenics, pitts, compostela, implants, sore, dentists,
# Nearest to their: its, his, her, the, our, your, my, some,
# Nearest to use: because, reason, sense, repair, unfashionable, range, most, quadrilateral,
# Nearest to for: including, of, wobble, without, dejima, if, code, against,
# Nearest to they: we, there, you, he, she, these, cindy, it,
# Nearest to four: eight, six, five, seven, three, nine, zero, two,
# Nearest to known: regarded, used, well, such, demonstrable, described, considered, called,
# Nearest to one: eight, four, two, nine, seven, six, five, three,
# Nearest to war: arisen, conflict, terabytes, denizens, espoo, meditating, inn, mages,
# Nearest to zero: five, eight, four, six, seven, nine, three, two,
# Nearest to seven: eight, four, nine, five, six, three, zero, one,
# Nearest to will: would, may, could, can, must, should, might, cannot,
# Nearest to time: year, way, balaton, period, yahweh, eminent, title, taxicab,
# Nearest to three: four, five, six, eight, seven, two, nine, zero,
# Nearest to history: origins, sem, list, stills, reclassification, scenic, retaining, geography,
# Average loss at step 62000: 3.238952
# Average loss at step 64000: 3.251346
# Average loss at step 66000: 3.410133
# Average loss at step 68000: 3.390236
# Average loss at step 70000: 3.360370
# Nearest to during: after, before, in, at, following, although, when, through,
# Nearest to with: between, implants, hieroglyphs, including, pitts, into, raw, using,
# Nearest to their: its, his, her, the, your, our, my, some,
# Nearest to use: range, most, repair, lick, because, reason, stol, prohibit,
# Nearest to for: including, while, against, in, without, of, starving, to,
# Nearest to they: we, there, you, he, it, she, these, then,
# Nearest to four: six, five, seven, three, eight, two, zero, nine,
# Nearest to known: regarded, used, such, well, described, seen, demonstrable, called,
# Nearest to one: two, six, seven, four, five, eight, nine, three,
# Nearest to war: arisen, during, conflict, meditating, terabytes, delay, inn, seemingly,
# Nearest to zero: five, six, four, eight, seven, nine, two, three,
# Nearest to seven: six, eight, four, nine, five, three, two, zero,
# Nearest to will: would, could, may, can, must, should, might, cannot,
# Nearest to time: year, period, way, title, dragonfly, summarised, reorganised, eminent,
# Nearest to three: four, six, two, seven, five, eight, nine, zero,
# Nearest to history: list, sem, origins, stills, reclassification, tobias, maud, scenic,
# Average loss at step 72000: 3.378154
# Average loss at step 74000: 3.346329
# Average loss at step 76000: 3.317674
# Average loss at step 78000: 3.345789
# Average loss at step 80000: 3.379872
# Nearest to during: after, when, in, before, through, despite, following, throughout,
# Nearest to with: between, hieroglyphs, in, naked, into, implants, deflate, irons,
# Nearest to their: its, his, her, your, our, my, whose, them,
# Nearest to use: because, cause, support, sense, prohibit, repair, range, amicable,
# Nearest to for: dev, including, against, expatriates, rocket, zinn, narcissus, agora,
# Nearest to they: we, he, you, there, she, it, these, who,
# Nearest to four: five, six, seven, eight, three, two, nine, zero,
# Nearest to known: regarded, used, described, seen, referred, such, called, well,
# Nearest to one: seven, six, two, eight, four, five, three, nine,
# Nearest to war: arisen, dewar, delay, conflict, wars, interracial, apparatus, nanjing,
# Nearest to zero: five, seven, six, eight, four, nine, three, two,
# Nearest to seven: five, eight, six, four, nine, three, zero, two,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to time: year, balaton, title, period, victory, yahweh, assigning, reorganised,
# Nearest to three: six, five, four, seven, eight, two, nine, zero,
# Nearest to history: list, sem, origins, reclassification, stills, communication, overview, maud,
# Average loss at step 82000: 3.408312
# Average loss at step 84000: 3.407961
# Average loss at step 86000: 3.388451
# Average loss at step 88000: 3.351831
# Average loss at step 90000: 3.366504
# Nearest to during: after, in, before, when, through, despite, throughout, at,
# Nearest to with: between, hieroglyphs, cvn, by, in, into, including, irons,
# Nearest to their: its, his, her, my, your, our, them, whose,
# Nearest to use: because, most, support, prom, sense, lick, addition, treatment,
# Nearest to for: including, without, of, against, by, after, while, until,
# Nearest to they: we, he, you, there, she, it, i, frigg,
# Nearest to four: five, seven, six, eight, three, two, nine, one,
# Nearest to known: regarded, used, described, such, seen, called, well, referred,
# Nearest to one: seven, four, two, six, eight, three, five, nine,
# Nearest to war: conflict, arisen, delay, wars, dewar, arab, during, nato,
# Nearest to zero: five, six, seven, eight, nine, four, three, two,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to time: year, period, title, victory, manner, matrimony, balaton, months,
# Nearest to three: five, two, four, eight, seven, six, nine, zero,
# Nearest to history: list, origins, reclassification, masada, stills, sem, development, efficiencies,
# Average loss at step 92000: 3.396389
# Average loss at step 94000: 3.254275
# Average loss at step 96000: 3.357029
# Average loss at step 98000: 3.240142
# Average loss at step 100000: 3.356238
# Nearest to during: after, in, before, following, throughout, when, through, at,
# Nearest to with: between, hieroglyphs, including, at, when, into, in, cvn,
# Nearest to their: its, his, her, your, our, the, my, whose,
# Nearest to use: cause, sense, most, because, yield, lick, support, notion,
# Nearest to for: when, while, mutinied, including, without, dispel, if, after,
# Nearest to they: we, there, he, you, she, it, i, these,
# Nearest to four: six, seven, five, eight, two, nine, three, zero,
# Nearest to known: regarded, such, described, seen, used, possible, well, referred,
# Nearest to one: two, four, seven, eight, five, six, nine, three,
# Nearest to war: wars, arisen, conflict, delay, dewar, telugu, terabytes, buber,
# Nearest to zero: five, eight, seven, six, nine, four, two, three,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to time: year, period, boredom, assigning, vesta, way, arson, life,
# Nearest to three: five, six, four, two, seven, eight, nine, zero,
# Nearest to history: list, reclassification, sem, masada, map, layer, bald, icons,

# %%
print(final_embeddings.shape)
# Out:
# (50000, 256)

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_cbow_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[target]
      labels[i * num_skips + j, 0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_cbow_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of', 'abuse', 'term', 'first', 'of', 'abuse', 'used', 'first', 'against']
#     labels: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['originated', 'term', 'a', 'anarchism', 'originated', 'of', 'as', 'term', 'of', 'as', 'abuse', 'a', 'a', 'first', 'abuse', 'term']
#     labels: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.695084
# Nearest to with: semiotics, trumpets, calculators, persson, viz, petal, countercult, bae,
# Nearest to called: wolfhound, whore, redeveloped, ssang, grandparents, romain, rimbaud, templars,
# Nearest to their: meltdown, desist, sliding, symbolized, seek, mellaart, priest, servlet,
# Nearest to one: mbe, benedictine, elway, formalisms, basie, nimh, youngest, filmmaker,
# Nearest to united: compensation, citation, hungary, miniature, uncover, weidenfeld, zulu, semiconducting,
# Nearest to been: dahomey, groupoids, comers, opted, ffg, aldebaran, anvil, commemoration,
# Nearest to they: convince, hermes, bloemfontein, disguised, no, equestrian, realist, stretched,
# Nearest to of: riddled, ritually, ricans, jd, homebrew, uucp, haircut, elohim,
# Nearest to other: electroweak, antofagasta, intellectual, axel, uf, statewide, fondly, granite,
# Nearest to and: encarta, guattari, kaplan, diverse, brawl, kabbalah, opium, raising,
# Nearest to who: matisse, obtaining, tyrrhenian, xml, cricketers, entropic, amendments, bel,
# Nearest to had: gotthold, recount, revoluci, familial, bazin, michel, rarities, succumbing,
# Nearest to it: influence, muscular, clinton, desires, twenties, expending, bangui, adjudication,
# Nearest to new: woodcock, anita, advertise, hfs, latest, comprehended, encamped, apartment,
# Nearest to as: slipped, norbert, thereby, exits, micrometres, eurozone, premillennialism, bennington,
# Nearest to not: amphitheatre, cheerleader, ginger, makarios, deianira, elmendorf, esiason, plotters,
# Average loss at step 2000: 4.367489
# Average loss at step 4000: 3.866647
# Average loss at step 6000: 3.785326
# Average loss at step 8000: 3.690805
# Average loss at step 10000: 3.615445
# Nearest to with: southwest, flaw, own, zachary, semiotics, gull, for, countercult,
# Nearest to called: redeveloped, reverse, travis, discounted, wolfhound, abilene, threonine, salvator,
# Nearest to their: his, its, the, kaddish, sliding, interphase, hep, her,
# Nearest to one: two, three, four, six, five, seven, eight, coated,
# Nearest to united: zulu, compensation, citation, hungary, whereof, erbium, sect, miniature,
# Nearest to been: mattia, be, had, were, was, comers, mortimer, votes,
# Nearest to they: he, we, it, multinational, you, cortes, no, not,
# Nearest to of: in, remit, and, secular, on, at, same, transliterations,
# Nearest to other: intellectual, edlin, rhythmically, microcode, supernatural, spun, granite, proximity,
# Nearest to and: or, of, american, who, liturgical, rooftops, kimi, outreach,
# Nearest to who: cricketers, he, recognizably, often, and, brahms, also, limburg,
# Nearest to had: has, have, was, bogdanovich, fayetteville, also, never, middleweight,
# Nearest to it: he, this, there, which, they, she, we, not,
# Nearest to new: anita, tutu, pint, remotely, latest, carnal, rubin, comprehended,
# Nearest to as: by, impregnated, codified, audiovisual, cody, into, baines, squid,
# Nearest to not: heretofore, it, they, sometimes, manichaeism, almost, enterprises, generally,
# Average loss at step 12000: 3.600211
# Average loss at step 14000: 3.569508
# Average loss at step 16000: 3.407318
# Average loss at step 18000: 3.461303
# Average loss at step 20000: 3.534991
# Nearest to with: in, flaw, for, transhumanism, between, by, bipeds, countercult,
# Nearest to called: travis, salvator, threonine, redeveloped, freud, stile, dobson, lindbergh,
# Nearest to their: his, its, her, the, some, kaddish, freebase, delayed,
# Nearest to one: two, four, three, six, eight, seven, five, nine,
# Nearest to united: zulu, compensation, same, northern, whereof, citation, next, hungary,
# Nearest to been: be, become, was, had, were, mattia, by, technological,
# Nearest to they: he, we, there, you, it, multinational, i, who,
# Nearest to of: opcw, for, ricans, ritually, main, original, dih, in,
# Nearest to other: many, these, rhythmically, granite, rebelling, such, spun, several,
# Nearest to and: or, but, in, interpolating, although, from, mani, inaccuracy,
# Nearest to who: he, which, cricketers, brahms, often, they, also, tensile,
# Nearest to had: has, have, was, were, bogdanovich, been, never, configuration,
# Nearest to it: he, there, this, she, which, they, not, we,
# Nearest to new: anita, rubin, tutu, rockstar, contralto, pint, factoring, carnal,
# Nearest to as: cody, catus, fists, impregnated, constructions, audiovisual, if, partners,
# Nearest to not: to, heretofore, enterprises, almost, also, largely, it, generally,
# Average loss at step 22000: 3.501452
# Average loss at step 24000: 3.487176
# Average loss at step 26000: 3.480191
# Average loss at step 28000: 3.478818
# Average loss at step 30000: 3.501339
# Nearest to with: between, including, zachary, flaw, captives, in, countercult, by,
# Nearest to called: salvator, dworkin, stile, travis, threonine, reykjav, freud, voyager,
# Nearest to their: its, his, her, the, some, these, many, ae,
# Nearest to one: two, seven, three, four, six, eight, five, nine,
# Nearest to united: zulu, same, northern, compensation, laity, whereof, miriam, sect,
# Nearest to been: become, be, was, were, had, technological, mattia, biomechanics,
# Nearest to they: we, there, he, you, it, these, who, not,
# Nearest to of: in, and, opcw, for, backfire, lagrange, christophe, among,
# Nearest to other: these, rhythmically, many, different, granite, cnidaria, are, several,
# Nearest to and: or, in, although, of, auc, but, who, grassy,
# Nearest to who: he, which, they, cricketers, limburg, tufts, she, often,
# Nearest to had: have, has, was, were, never, been, bogdanovich, fayetteville,
# Nearest to it: he, there, she, this, they, which, never, we,
# Nearest to new: anita, rubin, major, tutu, eliza, rockstar, stickers, pint,
# Nearest to as: by, redeeming, golem, iers, audiovisual, squid, siegel, mcmaster,
# Nearest to not: almost, they, heretofore, enterprises, sometimes, there, generally, still,
# Average loss at step 32000: 3.502126
# Average loss at step 34000: 3.495271
# Average loss at step 36000: 3.457164
# Average loss at step 38000: 3.302707
# Average loss at step 40000: 3.436966
# Nearest to with: between, euphonium, against, by, riyadh, including, flaw, jvm,
# Nearest to called: salvator, travis, threonine, resolvers, freyr, seventeenth, named, dworkin,
# Nearest to their: its, his, her, the, kaddish, some, him, these,
# Nearest to one: seven, two, three, five, eight, four, six, nine,
# Nearest to united: compensation, zulu, sinking, northern, southern, miriam, same, whereof,
# Nearest to been: become, be, was, were, officially, peremptory, had, mattia,
# Nearest to they: we, there, he, you, these, it, multinational, i,
# Nearest to of: for, smilga, frivolity, from, in, tees, omar, abhidharma,
# Nearest to other: different, filler, various, granite, cnidaria, omari, spun, many,
# Nearest to and: or, but, rasterization, which, diamagnetic, reddy, keiretsu, image,
# Nearest to who: which, he, often, also, they, she, cricketers, that,
# Nearest to had: has, have, was, were, bogdanovich, since, having, became,
# Nearest to it: he, there, she, this, they, not, which, often,
# Nearest to new: rubin, anita, major, contralto, latest, tutu, mangaverse, thorns,
# Nearest to as: muse, mcmaster, woodruff, baines, cylindrical, by, constructions, calicut,
# Nearest to not: it, generally, almost, still, sometimes, they, also, usually,
# Average loss at step 42000: 3.432972
# Average loss at step 44000: 3.452257
# Average loss at step 46000: 3.449177
# Average loss at step 48000: 3.355792
# Average loss at step 50000: 3.385434
# Nearest to with: between, when, repertory, predate, conical, by, document, adult,
# Nearest to called: salvator, stile, resolvers, dworkin, travis, named, threonine, freud,
# Nearest to their: its, his, her, the, kaddish, your, fargo, several,
# Nearest to one: two, six, seven, eight, three, four, five, nine,
# Nearest to united: northern, southern, compensation, sinking, zulu, tangents, worthington, laity,
# Nearest to been: become, was, be, were, already, had, peremptory, officially,
# Nearest to they: we, there, he, you, it, who, she, nobi,
# Nearest to of: in, ritually, opcw, omar, workability, during, osmond, and,
# Nearest to other: different, various, many, filler, several, granite, some, sanskrit,
# Nearest to and: or, but, including, transposed, of, through, pygmy, adverse,
# Nearest to who: he, which, she, often, they, cricketers, there, tensile,
# Nearest to had: has, have, was, were, having, bogdanovich, since, been,
# Nearest to it: he, she, there, this, they, xin, often, devo,
# Nearest to new: anita, corporate, latest, contralto, eliza, major, rubin, thorns,
# Nearest to as: substratum, codified, oppress, fawcett, constructions, too, apprenticed, usgs,
# Nearest to not: almost, generally, now, usually, heretofore, sometimes, methane, banished,
# Average loss at step 52000: 3.437811
# Average loss at step 54000: 3.425599
# Average loss at step 56000: 3.438104
# Average loss at step 58000: 3.393151
# Average loss at step 60000: 3.395966
# Nearest to with: between, including, flaw, in, without, when, countercult, among,
# Nearest to called: salvator, dworkin, named, used, stile, travis, threonine, freyr,
# Nearest to their: its, his, her, the, some, your, our, categorize,
# Nearest to one: two, eight, seven, four, five, nine, six, three,
# Nearest to united: southern, sinking, compensation, worthington, tangents, miriam, whereof, zulu,
# Nearest to been: become, be, was, were, minarchists, biomechanics, peremptory, had,
# Nearest to they: we, there, he, you, it, she, these, sequences,
# Nearest to of: in, same, for, ritually, opcw, incubation, tees, smilga,
# Nearest to other: different, many, various, filler, several, rhythmically, granite, spun,
# Nearest to and: or, but, including, among, through, nilsson, while, although,
# Nearest to who: he, she, which, now, usually, often, eventually, they,
# Nearest to had: has, have, was, were, having, yet, gave, skilling,
# Nearest to it: he, there, she, this, they, now, which, quotients,
# Nearest to new: anita, rubin, latest, contralto, major, hidalgo, wavering, factoring,
# Nearest to as: aoun, codified, mccay, too, constructions, chieftain, golem, iterations,
# Nearest to not: almost, generally, usually, nee, banished, it, they, now,
# Average loss at step 62000: 3.240407
# Average loss at step 64000: 3.258478
# Average loss at step 66000: 3.400114
# Average loss at step 68000: 3.394474
# Average loss at step 70000: 3.360014
# Nearest to with: between, abrasive, without, slams, to, if, flaw, including,
# Nearest to called: named, salvator, known, travis, used, rabelais, dworkin, scalability,
# Nearest to their: its, his, her, the, your, some, our, kaddish,
# Nearest to one: two, six, seven, four, eight, five, nine, three,
# Nearest to united: sinking, tangents, miriam, same, worthington, next, compensation, southern,
# Nearest to been: become, be, was, already, were, since, had, officially,
# Nearest to they: we, there, he, you, it, she, then, who,
# Nearest to of: including, include, and, opcw, although, for, specific, issn,
# Nearest to other: various, different, filler, many, rhythmically, granite, adequately, mortality,
# Nearest to and: or, but, of, which, while, to, although, recalls,
# Nearest to who: he, which, she, bafta, they, tufts, now, tensile,
# Nearest to had: has, have, was, were, having, rambling, gave, been,
# Nearest to it: he, there, she, this, they, now, itself, sibelius,
# Nearest to new: anita, wavering, modern, mangaverse, hidalgo, rubin, pinchcliffe, digital,
# Nearest to as: when, constructions, imbued, whampoa, shambhala, apprenticed, like, caa,
# Nearest to not: generally, almost, still, usually, now, heretofore, nee, never,
# Average loss at step 72000: 3.373428
# Average loss at step 74000: 3.348437
# Average loss at step 76000: 3.320493
# Average loss at step 78000: 3.349089
# Average loss at step 80000: 3.375373
# Nearest to with: between, flaw, jacobitism, jvm, when, waring, including, without,
# Nearest to called: named, used, salvator, known, scalability, rabelais, resolvers, travis,
# Nearest to their: its, his, her, your, our, kaddish, my, these,
# Nearest to one: seven, two, six, three, five, four, eight, nine,
# Nearest to united: sinking, miriam, worthington, same, tangents, constitution, compensation, southern,
# Nearest to been: become, be, already, were, officially, had, was, previously,
# Nearest to they: we, he, there, you, it, she, these, not,
# Nearest to of: in, including, omar, original, throttled, bugzilla, impunity, issn,
# Nearest to other: various, many, filler, different, rhythmically, granite, individual, several,
# Nearest to and: or, including, but, basing, howard, enid, jealousy, nilsson,
# Nearest to who: he, she, tensile, they, bafta, which, often, usually,
# Nearest to had: has, have, was, were, having, rambling, flu, been,
# Nearest to it: he, she, there, this, they, we, itself, microcontrollers,
# Nearest to new: anita, wavering, pinchcliffe, commemorations, transcendentalism, tutu, rubin, tigre,
# Nearest to as: swiss, cody, substratum, mccay, cowdery, imbued, flamenco, deserters,
# Nearest to not: usually, generally, still, they, almost, always, heretofore, summarize,
# Average loss at step 82000: 3.407512
# Average loss at step 84000: 3.410112
# Average loss at step 86000: 3.388219
# Average loss at step 88000: 3.353048
# Average loss at step 90000: 3.360570
# Nearest to with: between, by, in, repertory, captives, including, conical, jacobitism,
# Nearest to called: named, used, salvator, known, rabelais, considered, seventeenth, travis,
# Nearest to their: its, his, her, your, our, kaddish, my, themselves,
# Nearest to one: seven, eight, two, four, six, five, three, nine,
# Nearest to united: constitution, sinking, tangents, same, miriam, beatles, southern, acl,
# Nearest to been: become, be, already, was, were, being, makkah, previously,
# Nearest to they: we, there, he, you, she, it, who, these,
# Nearest to of: including, in, ritually, opcw, for, include, dih, supervise,
# Nearest to other: various, filler, rhythmically, others, individual, different, several, sanskrit,
# Nearest to and: or, but, including, bernardi, karaoke, while, through, basing,
# Nearest to who: he, she, they, often, also, abrams, which, tensile,
# Nearest to had: has, have, was, were, having, continued, since, suffered,
# Nearest to it: he, she, this, there, itself, they, often, sulfate,
# Nearest to new: particular, modern, rubin, anita, transcendentalism, ketchup, tigre, wavering,
# Nearest to as: landry, mccay, deserters, slaughters, sancho, swiss, pashto, mmorpgs,
# Nearest to not: still, generally, nee, almost, banished, also, summarize, nor,
# Average loss at step 92000: 3.402291
# Average loss at step 94000: 3.248544
# Average loss at step 96000: 3.361252
# Average loss at step 98000: 3.243897
# Average loss at step 100000: 3.353456
# Nearest to with: between, euphonium, jvm, semiotics, into, by, including, in,
# Nearest to called: named, salvator, known, travis, seventeenth, referred, rabelais, resolvers,
# Nearest to their: its, his, her, your, the, our, some, kaddish,
# Nearest to one: two, seven, five, hz, four, eight, six, three,
# Nearest to united: constitution, sinking, tangents, continental, same, southern, beatles, supreme,
# Nearest to been: become, be, already, was, since, were, recently, makkah,
# Nearest to they: we, there, he, you, she, it, not, i,
# Nearest to of: in, including, and, smilga, daemon, original, nonfiction, tees,
# Nearest to other: various, filler, several, individual, others, different, rhythmically, vaccines,
# Nearest to and: or, but, like, loathed, transposed, when, although, of,
# Nearest to who: he, she, that, never, now, still, usually, often,
# Nearest to had: has, have, was, were, since, having, is, empresses,
# Nearest to it: he, she, this, there, they, itself, often, simply,
# Nearest to new: modern, anita, hidalgo, mangaverse, rubin, wavering, tigre, particular,
# Nearest to as: mccay, like, lesund, saltwater, although, when, durch, suborders,
# Nearest to not: still, they, almost, generally, never, actually, nee, heretofore,

# %%
print(words[:10])
# Out:
# ['the', 'of', 'and', 'one', 'in', 'a', 'to', 'zero', 'nine', 'two']

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
batch_size = 128
embedding_size = 256 # Dimension of the embedding vector.
skip_window = 2 # How many words to consider left and right.
num_skips = 4 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.323823
# Nearest to all: solvents, archdiocese, resented, flower, keitel, jawaharlal, refutations, louvain,
# Nearest to his: pretender, milano, abauzit, quadriceps, bbses, lightfoot, be, st,
# Nearest to such: balzac, palatalization, moveable, antidepressant, retrieve, cushitic, blown, cracow,
# Nearest to also: rebellious, svante, hbar, spiny, picardy, meyers, baffled, caller,
# Nearest to it: sanjaks, strata, reap, seizures, bracelet, derby, practicality, zapotec,
# Nearest to s: pastimes, pelts, lethargy, plo, penile, concentrating, duffy, uncontrollably,
# Nearest to as: casket, irreversible, overarching, worthy, founds, assaulting, sufficient, alarms,
# Nearest to some: dating, nineties, cowley, realities, doing, chrysler, stative, contradicts,
# Nearest to years: marathi, tapping, army, recombination, rarely, clears, thank, knowledge,
# Nearest to about: parson, rule, breakthrough, soaring, kul, hillsdale, financed, uptown,
# Nearest to while: mta, sweetened, corroborating, strength, theories, alcoholics, xerox, velarized,
# Nearest to for: rik, xy, arianism, beecher, reduce, bouts, vindication, drafting,
# Nearest to no: illustrating, rotten, cistercians, cathy, examines, oglethorpe, transmembrane, ripley,
# Nearest to UNK: wise, paperbacks, cabins, equip, splines, universidad, planina, gaians,
# Nearest to between: deportation, iga, danse, hl, jellicoe, eliminating, grandson, perhaps,
# Nearest to b: endangering, cyrix, accusing, discord, parishioners, warriors, flagg, hazel,
# Average loss at step 2000: 4.599306
# Average loss at step 4000: 4.181993
# Average loss at step 6000: 4.031295
# Average loss at step 8000: 3.948257
# Average loss at step 10000: 3.984026
# Nearest to all: ili, solvents, folkestone, archdiocese, guppy, refutations, gorilla, splendid,
# Nearest to his: s, pretender, apollonia, motion, sprint, their, ethics, diets,
# Nearest to such: cracow, balzac, retrieve, blown, bestows, erp, sopranos, remorse,
# Nearest to also: svante, rebellious, baffled, presidential, which, histidine, sui, that,
# Nearest to it: he, this, not, parcels, that, which, be, reap,
# Nearest to s: and, his, peter, lees, awful, severus, five, rotational,
# Nearest to as: by, for, is, was, gossip, writers, with, in,
# Nearest to some: dating, nineties, realities, chrysler, loader, seem, doing, contradicts,
# Nearest to years: marathi, tapping, boise, rarely, knowledge, opcw, army, binomial,
# Nearest to about: rule, breakthrough, hillsdale, nephites, sickly, accommodation, malevich, fairey,
# Nearest to while: mta, sweetened, corroborating, theories, strength, alcoholics, eduardo, marr,
# Nearest to for: of, and, in, with, as, by, stairs, to,
# Nearest to no: giraffes, illustrating, oglethorpe, rotten, cormac, ripley, examines, pragmatics,
# Nearest to UNK: university, by, d, spearhead, catal, alc, spat, reprinted,
# Nearest to between: deportation, iga, perhaps, danse, crumbling, hl, unfair, harappan,
# Nearest to b: d, endangering, cyrix, pee, phillippe, cancers, mechanic, writer,
# Average loss at step 12000: 3.989049
# Average loss at step 14000: 3.905827
# Average loss at step 16000: 3.897444
# Average loss at step 18000: 3.782545
# Average loss at step 20000: 3.752182
# Nearest to all: amplified, some, ili, verbal, many, apostolic, material, fashioning,
# Nearest to his: their, s, the, a, its, her, garrisoned, iceberg,
# Nearest to such: well, diamagnets, balzac, or, benchmarking, humanitarians, webmaster, bestows,
# Nearest to also: which, that, kickoff, hussain, svante, punic, inbound, inductees,
# Nearest to it: this, he, there, which, not, that, simplest, ceilings,
# Nearest to s: his, escapement, buds, sulphate, hutchins, enthusiastically, helices, paternal,
# Nearest to as: UNK, can, is, in, laurentiis, overboard, hussain, are,
# Nearest to some: many, nineties, all, differ, postman, their, chrysler, realities,
# Nearest to years: opcw, boise, luigi, rarely, marathi, cosmopolitan, army, plotters,
# Nearest to about: breakthrough, rule, nephites, upstream, four, ypres, pinter, kul,
# Nearest to while: mta, sweetened, theories, strength, alcoholics, corroborating, marr, calendars,
# Nearest to for: of, stop, sweetheart, childs, dagesh, to, or, aims,
# Nearest to no: cormac, its, bet, oglethorpe, examines, uttar, illustrating, canine,
# Nearest to UNK: a, of, as, and, the, proxies, widdecombe, seljuk,
# Nearest to between: deportation, iga, consummate, harappan, fade, deeper, with, unfair,
# Nearest to b: d, cancers, cyrix, handgun, two, entrepreneur, three, phillippe,
# Average loss at step 22000: 3.854057
# Average loss at step 24000: 3.778415
# Average loss at step 26000: 3.784486
# Average loss at step 28000: 3.827725
# Average loss at step 30000: 3.817664
# Nearest to all: some, many, amplified, other, ili, dimensions, excise, these,
# Nearest to his: their, her, its, the, s, a, some, abrogation,
# Nearest to such: well, these, or, many, benchmarking, known, cracow, retrieve,
# Nearest to also: this, which, that, not, it, hussain, still, only,
# Nearest to it: he, this, which, there, not, that, but, never,
# Nearest to s: his, lonsdaleite, harbor, cheeks, wield, caroline, jameson, a,
# Nearest to as: schumacher, by, barbara, hong, kekkonen, baines, is, gossip,
# Nearest to some: many, all, other, their, his, these, chrysler, those,
# Nearest to years: opcw, five, boise, year, plotters, rarely, quinlan, time,
# Nearest to about: rule, nephites, breakthrough, upstream, antonio, than, canonicity, but,
# Nearest to while: mta, or, although, theories, against, sweetened, fen, marr,
# Nearest to for: with, hyperplasia, of, by, berber, dagesh, helices, as,
# Nearest to no: bet, its, although, militarism, termites, any, appia, postmodernists,
# Nearest to UNK: expulsions, afar, expositor, consume, j, in, mothers, r,
# Nearest to between: deportation, with, consummate, harappan, cumbric, through, raaf, in,
# Nearest to b: d, x, c, cancers, zero, one, nbc, i,
# Average loss at step 32000: 3.815682
# Average loss at step 34000: 3.821521
# Average loss at step 36000: 3.767509
# Average loss at step 38000: 3.725526
# Average loss at step 40000: 3.769980
# Nearest to all: some, many, any, these, they, do, other, gatling,
# Nearest to his: their, her, its, s, thoroughfare, azariah, own, unsolved,
# Nearest to such: well, these, other, known, bestows, leather, explicated, cracow,
# Nearest to also: which, that, been, not, this, still, often, it,
# Nearest to it: he, this, which, she, there, not, that, they,
# Nearest to s: his, its, UNK, and, uiuc, har, serialised, two,
# Nearest to as: in, when, known, of, can, is, gossip, confederation,
# Nearest to some: many, these, most, other, all, several, their, they,
# Nearest to years: year, opcw, boise, zero, seven, five, plotters, hardens,
# Nearest to about: upstream, when, folklorist, links, decaying, nephites, seven, than,
# Nearest to while: against, mta, although, and, strength, blogger, theories, paddle,
# Nearest to for: of, to, and, if, with, laurentian, or, contemplating,
# Nearest to no: a, although, this, bet, mice, an, giraffes, any,
# Nearest to UNK: and, s, e, targets, deformity, orchid, geneva, importer,
# Nearest to between: with, deportation, in, consummate, of, harappan, anatomist, at,
# Nearest to b: d, e, snowball, and, cancers, c, logarithmically, bittersweet,
# Average loss at step 42000: 3.675059
# Average loss at step 44000: 3.697827
# Average loss at step 46000: 3.661182
# Average loss at step 48000: 3.628196
# Average loss at step 50000: 3.767920
# Nearest to all: some, other, many, any, justin, most, these, amplified,
# Nearest to his: their, her, its, s, dmitri, those, angleton, formalize,
# Nearest to such: well, known, other, strabo, deplete, explicated, these, zodiacal,
# Nearest to also: not, which, that, often, only, this, be, unwillingness,
# Nearest to it: he, this, there, which, not, they, what, she,
# Nearest to s: his, two, ebro, pbk, reopen, fim, mormon, sulphate,
# Nearest to as: not, UNK, cannot, by, deleterious, enough, in, is,
# Nearest to some: many, all, these, those, several, most, their, other,
# Nearest to years: year, opcw, decades, boise, accident, rarely, undeclared, times,
# Nearest to about: upstream, interval, than, financed, antonio, nephites, links, breakthrough,
# Nearest to while: and, although, mta, strength, calendars, against, govt, aise,
# Nearest to for: if, and, on, at, after, of, bodhisattvas, vil,
# Nearest to no: a, any, bjp, only, also, appia, been, comoros,
# Nearest to UNK: and, as, thuringiensis, cheerful, riff, fida, swept, firsts,
# Nearest to between: with, deportation, consummate, from, cumbric, harappan, unfair, affects,
# Nearest to b: d, e, actress, c, skeleton, codon, endangering, flagg,
# Average loss at step 52000: 3.736358
# Average loss at step 54000: 3.566324
# Average loss at step 56000: 3.728896
# Average loss at step 58000: 3.632672
# Average loss at step 60000: 3.686021
# Nearest to all: many, some, these, justin, other, those, any, administers,
# Nearest to his: her, their, its, the, s, angleton, my, dmitri,
# Nearest to such: well, known, these, other, many, postpositions, including, bogot,
# Nearest to also: only, which, punic, whammy, often, sometimes, it, stopper,
# Nearest to it: he, this, she, they, there, only, also, constantly,
# Nearest to s: his, nj, pyotr, and, american, multivariate, greenhouse, ratzinger,
# Nearest to as: by, well, in, mackinac, polis, ventricles, latinos, and,
# Nearest to some: many, these, those, several, all, most, other, others,
# Nearest to years: year, opcw, decades, days, times, boise, time, months,
# Nearest to about: upstream, on, breakthrough, financed, that, interval, nephites, folklorist,
# Nearest to while: although, when, against, freeware, zechariah, still, and, airwaves,
# Nearest to for: of, in, including, and, buttocks, to, findable, with,
# Nearest to no: any, only, another, a, auctioned, buena, postfix, bjp,
# Nearest to UNK: and, t, n, k, m, a, albrecht, o,
# Nearest to between: with, deportation, consummate, fade, typological, harappan, when, toolbars,
# Nearest to b: d, thermonuclear, intuitionist, landslides, impeachment, actress, br, waldo,
# Average loss at step 62000: 3.648881
# Average loss at step 64000: 3.553301
# Average loss at step 66000: 3.729465
# Average loss at step 68000: 3.747637
# Average loss at step 70000: 3.742444
# Nearest to all: some, many, these, are, other, several, those, various,
# Nearest to his: their, her, its, s, the, these, an, angleton,
# Nearest to such: well, known, these, as, postpositions, served, many, other,
# Nearest to also: which, often, sometimes, since, been, punic, although, freeza,
# Nearest to it: he, this, only, there, she, they, but, which,
# Nearest to s: four, his, its, synonymously, smyth, violence, taxa, abdali,
# Nearest to as: comeback, for, such, well, known, boric, divides, suppressor,
# Nearest to some: many, several, these, those, all, most, their, other,
# Nearest to years: year, decades, days, months, opcw, szabo, trakai, times,
# Nearest to about: upstream, telstar, antonio, breakthrough, although, on, folklorist, posture,
# Nearest to while: although, however, when, but, and, zechariah, straightforwardly, govt,
# Nearest to for: of, including, and, after, with, system, as, schulz,
# Nearest to no: only, another, disciplinary, any, a, its, pechenegs, appia,
# Nearest to UNK: tillich, gnu, commanded, richard, simulators, bos, customers, abbas,
# Nearest to between: with, deportation, during, raaf, toolbars, since, typological, on,
# Nearest to b: d, e, five, six, x, four, ediacaran, t,
# Average loss at step 72000: 3.672189
# Average loss at step 74000: 3.701192
# Average loss at step 76000: 3.700273
# Average loss at step 78000: 3.605626
# Average loss at step 80000: 3.404306
# Nearest to all: some, are, many, several, any, these, various, their,
# Nearest to his: her, their, its, the, him, died, s, glaring,
# Nearest to such: well, known, result, postpositions, include, leather, many, evaporating,
# Nearest to also: which, now, however, not, that, been, only, where,
# Nearest to it: he, this, she, only, there, they, that, which,
# Nearest to s: its, livia, his, pastimes, handmade, pompidou, ridley, schism,
# Nearest to as: well, known, by, patenting, irt, botanical, chu, such,
# Nearest to some: many, several, all, other, these, those, various, most,
# Nearest to years: year, months, days, opcw, five, over, decades, nine,
# Nearest to about: over, zero, upstream, devastation, breakthrough, than, recycling, salvadorans,
# Nearest to while: however, although, and, but, where, when, of, from,
# Nearest to for: to, of, after, by, with, including, in, first,
# Nearest to no: only, not, any, a, another, the, churning, its,
# Nearest to UNK: or, de, of, and, in, san, trujillo, n,
# Nearest to between: with, into, through, since, in, during, fade, within,
# Nearest to b: d, f, e, c, g, mathbf, t, actress,
# Average loss at step 82000: 3.764603
# Average loss at step 84000: 3.685000
# Average loss at step 86000: 3.644474
# Average loss at step 88000: 3.710259
# Average loss at step 90000: 3.718932
# Nearest to all: some, many, any, both, several, were, these, each,
# Nearest to his: their, her, its, s, the, catastrophes, life, belichick,
# Nearest to such: well, including, known, other, many, evaporating, mjh, served,
# Nearest to also: often, which, now, what, sometimes, although, theosophical, punic,
# Nearest to it: he, this, there, only, she, still, what, widely,
# Nearest to s: his, of, and, bl, futurist, biot, one, goalscorer,
# Nearest to as: bylaws, gringo, mildly, eggplant, inti, such, ishiro, ordinances,
# Nearest to some: many, all, several, most, those, other, various, any,
# Nearest to years: year, days, months, decades, times, opcw, centuries, weeks,
# Nearest to about: over, four, than, on, fluorine, upstream, devastation, robin,
# Nearest to while: however, although, where, but, when, though, aise, still,
# Nearest to for: with, including, and, of, canto, turing, crematoria, on,
# Nearest to no: any, only, not, another, rearranging, metalloid, directv, appia,
# Nearest to UNK: and, l, de, falconer, www, du, n, of,
# Nearest to between: with, into, within, deportation, in, fade, rhys, ola,
# Nearest to b: d, f, mathbf, e, c, g, ashkenazim, biker,
# Average loss at step 92000: 3.707974
# Average loss at step 94000: 3.708659
# Average loss at step 96000: 3.685267
# Average loss at step 98000: 3.707209
# Average loss at step 100000: 3.674254
# Nearest to all: many, some, both, these, other, any, various, most,
# Nearest to his: their, her, its, the, s, these, a, them,
# Nearest to such: well, including, known, other, evaporating, many, these, described,
# Nearest to also: which, that, where, when, sometimes, although, what, said,
# Nearest to it: he, this, there, she, they, what, always, now,
# Nearest to s: his, mongoloids, homophonic, xl, two, chainmail, tehran, nepal,
# Nearest to as: UNK, known, well, neely, such, for, materially, that,
# Nearest to some: many, several, most, those, various, all, other, these,
# Nearest to years: year, months, days, decades, times, weeks, opcw, centuries,
# Nearest to about: over, on, than, more, devastation, upstream, lastly, from,
# Nearest to while: although, however, where, when, or, though, before, aise,
# Nearest to for: of, after, rabbis, in, while, as, to, expanding,
# Nearest to no: any, a, not, little, another, only, less, an,
# Nearest to UNK: pat, as, a, and, beasts, the, appearing, tin,
# Nearest to between: within, with, deportation, typological, into, in, through, raaf,
# Nearest to b: d, f, e, mathbf, c, h, g, ashkenazim,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

plot(two_d_embeddings, words)
